# %% [markdown]
# __11/12/2020__
#
# Beatriz Cárdaba Rico
#
# Sara Bengoechea Rodríguez

# %% [markdown]
# # IMPORT DATA

# %%
import numpy as np
import pandas as pd

# %%
df1 = pd.read_csv('../data/01_raw/Loan_training_set_1_4.csv', skiprows = 1,  skipfooter=2, engine='python')

# %%
df1.head()
# Out:
#           id  member_id  loan_amnt  funded_amnt  funded_amnt_inv        term  \
# 0  112435993        NaN       2300         2300             2300   36 months
# 1  112290210        NaN      16000        16000            16000   60 months
# 2  112436985        NaN       6025         6025             6025   36 months
# 3  112439006        NaN      20400        20400            20400   36 months
# 4  112438929        NaN      13000        13000            13000   36 months
#
#   int_rate  installment grade sub_grade  ... hardship_payoff_balance_amount  \
# 0   12.62%        77.08     C        C1  ...                            NaN
# 1   12.62%       360.95     C        C1  ...                            NaN
# 2   15.05%       209.01     C        C4  ...                            NaN
# 3    9.44%       652.91     B        B1  ...                            NaN
# 4   11.99%       431.73     B        B5  ...                            NaN
#
# ...

# %%
df1.tail()
# Out:
#                id  member_id  loan_amnt  funded_amnt  funded_amnt_inv  \
# 105446  102556443        NaN      24000        24000            24000
# 105447  102653304        NaN      10000        10000            10000
# 105448  102628603        NaN      10050        10050            10050
# 105449  102196576        NaN       6000         6000             6000
# 105450   99799684        NaN      30000        30000            30000
#
#               term int_rate  installment grade sub_grade  ...  \
# 105446   60 months   23.99%       690.30     E        E2  ...
# 105447   36 months    7.99%       313.32     A        A5  ...
# 105448   36 months   16.99%       358.26     D        D1  ...
# 105449   36 months   11.44%       197.69     B        B4  ...
# 105450   60 months   25.49%       889.18     E        E4  ...
#
#        hardship_payoff_balance_amount hardship_last_payment_amount  \
# 105446                            NaN                          NaN
# ...

# %%
df1.shape
# Out:
# (105451, 151)

# %%
len(df1.columns)
# Out:
# 151

# %%
df2 = pd.read_csv('../data/01_raw/Loan_training_set_2_4.csv', skiprows = 1, engine='python', skipfooter=2)

# %%
df2.tail()
# Out:
#                id  member_id  loan_amnt  funded_amnt  funded_amnt_inv  \
# 122696  110380307        NaN       6000         6000             6000
# 122697  110479222        NaN      20000        20000            20000
# 122698  109866673        NaN      35000        35000            35000
# 122699  110394553        NaN      30775        30775            30525
# 122700  109517381        NaN      18900        18900            18900
#
#               term int_rate  installment grade sub_grade  ...  \
# 122696   36 months   23.88%       235.02     E        E2  ...
# 122697   60 months   26.30%       602.37     E        E5  ...
# 122698   60 months   30.89%      1151.58     G        G3  ...
# 122699   60 months   30.65%      1008.00     F        F4  ...
# 122700   60 months   30.94%       622.44     G        G4  ...
#
#        hardship_payoff_balance_amount hardship_last_payment_amount  \
# 122696                            NaN                          NaN
# ...

# %%
df2.shape
# Out:
# (122701, 151)

# %%
df3 = pd.read_csv('../data/01_raw/Loan_training_set_3_4.csv', skiprows = 1, skipfooter = 2, engine = 'python')

# %%
import sys
sys.maxsize > 2**32
# Out:
# True

# %%
df3.tail()
# Out:
#              id  member_id  loan_amnt  funded_amnt  funded_amnt_inv  \
# 235624  8598660        NaN      18400        18400            18400
# 235625  9684700        NaN      22000        22000            22000
# 235626  9604874        NaN       2000         2000             2000
# 235627  9584776        NaN      20700        20700            20700
# 235628  9199665        NaN      10000        10000             9975
#
#               term int_rate  installment grade sub_grade  ...  \
# 235624   60 months   14.47%       432.64     C        C2  ...
# 235625   60 months   19.97%       582.50     D        D5  ...
# 235626   36 months    7.90%        62.59     A        A4  ...
# 235627   60 months   16.99%       514.34     D        D1  ...
# 235628   36 months   19.20%       367.58     D        D3  ...
#
#        hardship_payoff_balance_amount hardship_last_payment_amount  \
# 235624                            NaN                          NaN
# ...

# %%
df4 = pd.read_csv('../data/01_raw/Loan_training_set_4_4.csv', skiprows = 1, skipfooter=2, engine = 'python') # Probar a poner lo de

# %%
df4.head()
# Out:
#          id  member_id  loan_amnt  funded_amnt  funded_amnt_inv        term  \
# 0  68506789        NaN      12000        12000          12000.0   60 months
# 1  68426545        NaN      16000        16000          16000.0   60 months
# 2  68394562        NaN      30000        30000          30000.0   36 months
# 3  66583801        NaN      33600        33600          33600.0   36 months
# 4  68466916        NaN      25000        25000          25000.0   36 months
#
#   int_rate  installment grade sub_grade  ... hardship_payoff_balance_amount  \
# 0    9.80%       253.79     B        B3  ...                            NaN
# 1   12.88%       363.07     C        C2  ...                            NaN
# 2   15.77%      1051.31     D        D1  ...                            NaN
# 3   10.78%      1096.53     B        B4  ...                            NaN
# 4    7.49%       777.55     A        A4  ...                            NaN
#
# ...

# %%
df4.tail()
# Out:
#               id  member_id  loan_amnt  funded_amnt  funded_amnt_inv  \
# 421090  36371250        NaN      10000        10000          10000.0
# 421091  36441262        NaN      24000        24000          24000.0
# 421092  36271333        NaN      13000        13000          13000.0
# 421093  36490806        NaN      12000        12000          12000.0
# 421094  36271262        NaN      20000        20000          20000.0
#
#               term int_rate  installment grade sub_grade  ...  \
# 421090   36 months   11.99%       332.10     B        B5  ...
# 421091   36 months   11.99%       797.03     B        B5  ...
# 421092   60 months   15.99%       316.07     D        D2  ...
# 421093   60 months   19.99%       317.86     E        E3  ...
# 421094   36 months   11.99%       664.20     B        B5  ...
#
#        hardship_payoff_balance_amount hardship_last_payment_amount  \
# 421090                            NaN                          NaN
# ...

# %%
# Creamos un df con todos los ficheros
frames = [df1, df2, df3, df4]

# %%
loan_all = pd.concat(frames)

# %%
loan_all.head(5)
# Out:
#           id  member_id  loan_amnt  funded_amnt  funded_amnt_inv        term  \
# 0  112435993        NaN       2300         2300           2300.0   36 months
# 1  112290210        NaN      16000        16000          16000.0   60 months
# 2  112436985        NaN       6025         6025           6025.0   36 months
# 3  112439006        NaN      20400        20400          20400.0   36 months
# 4  112438929        NaN      13000        13000          13000.0   36 months
#
#   int_rate  installment grade sub_grade  ... hardship_payoff_balance_amount  \
# 0   12.62%        77.08     C        C1  ...                            NaN
# 1   12.62%       360.95     C        C1  ...                            NaN
# 2   15.05%       209.01     C        C4  ...                            NaN
# 3    9.44%       652.91     B        B1  ...                            NaN
# 4   11.99%       431.73     B        B5  ...                            NaN
#
# ...

# %%
# Creamos un csv con el df completo con todo el data llamado loan_all situado en la 
# siguiente ruta
ruta = '../data/01_raw/loan_all.csv'

# %%
loan_all.to_csv(ruta)
